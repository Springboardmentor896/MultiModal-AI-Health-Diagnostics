# %%
import sys
import os
import json
import glob
import pandas as pd

# %%
sys.path.append(os.path.abspath('..'))

# %%
from ingestion.ocr_parser import extract_text
from extract.extract import smart_parse_and_correct
from validation.validator import standardize_units
from models.model import interpret_results

# %%
IMAGE_DIR = "/home/quasar_011/Developer/v_intern/data/sample/"
REF_RANGES_PATH = "/home/quasar_011/Developer/v_intern/validation/reference_ranges.json"

# %%
image_paths = glob.glob(os.path.join(IMAGE_DIR, "*.jpg")) + \
              glob.glob(os.path.join(IMAGE_DIR, "*.png"))


print(f"Found {len(image_paths)} images to process.")
# Out:
# Found 12 images to process.

# %%
all_patients_summary = []

for i, img_path in enumerate(image_paths, 1):
    filename = os.path.basename(img_path)
    print(f"\n[{i}/{len(image_paths)}] Processing: {filename}...")
    
    try:
        raw_text = extract_text(img_path)
        if not raw_text:
            print("   (Skipping: OCR returned empty text)")
            continue
            
        extracted_data = smart_parse_and_correct(raw_text)
        
        standardized_data = standardize_units(extracted_data)
        
        final_report = interpret_results(standardized_data, REF_RANGES_PATH)
        
        if final_report:
            print(f"   -> Found {len(final_report)} parameters.")
            
            for item in final_report:
                all_patients_summary.append({
                    "File": filename,
                    "Parameter": item['Parameter'],
                    "Value": item['Value'],
                    "Unit": item['Unit'],
                    "Status": item['Status'],
                    "Interpretation": item['Note']
                })
        else:
            print("   -> No parameters extracted (Check image quality or format).")
            
    except Exception as e:
        print(f"   (!) Error processing {filename}: {e}")
# Out:
# [1/12] Processing: sample.png...
#    -> Found 14 parameters.
#
# [2/12] Processing: AHD-0425-PA-0007719_E-REPORTS_250427_2032@E.pdf_page_7.png...
#    -> Found 21 parameters.
#
# [3/12] Processing: AHD-0425-PA-0008061_E-mahendrasinghdischargecard_250427_1114@E.pdf_page_13.png...
#    -> Found 11 parameters.
#
# [4/12] Processing: AHD-0425-PA-0008061_E-mahendrasinghdischargecard_250427_1114@E.pdf_page_27.png...
#    -> Found 14 parameters.
#
# [5/12] Processing: BLR-0425-PA-0036693_ARVIND REDDY REPALA 0036693_28-04-2025_1120-45_AM@E.pdf_page_24.png...
#    -> Found 14 parameters.
#
# [6/12] Processing: BLR-0425-PA-0039320_501848074 Final bill and DS   26042025_27-04-2025_1054-20_AM.pdf_page_10.png...
#    -> Found 13 parameters.
#
# [7/12] Processing: BLR-0425-PA-0040880_E-1745741621426SUSHILADEVIds_250427_1347@E.pdf_page_2.png...
#    -> Found 21 parameters.
#
# [8/12] Processing: BLR-0425-PA-0041078_D CARD AND REPORT_11zon_27-04-2025_1204-56_PM.pdf_page_8.png...
#    -> Found 3 parameters.
#
# [9/12] Processing: BLR-0425-PA-0041109_F-PREAUTH202504230003_250423_1752@G.pdf_page_7.png...
#    -> No parameters extracted (Check image quality or format).
#
# [10/12] Processing: BLR-0425-PA-0041313_F-sudhirpreauth_250424_1309@G.pdf_page_14.png...
#    -> Found 19 parameters.
#
# [11/12] Processing: BLR-0425-PA-0041374_E-REPORT_250427_1413@E.pdf_page_2.png...
#    -> Found 14 parameters.
#
# [12/12] Processing: BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905cf4d4a1_27-04-2025_0520-51_PM@E.pdf_page_14.png...
#    -> Found 18 parameters.

# %%
if all_patients_summary:
    df = pd.DataFrame(all_patients_summary)
    
    cols = ["File", "Parameter", "Value", "Unit", "Status", "Interpretation"]
    df = df[cols]
    
    from IPython.display import display
    
    print("\n--- All Extracted Data ---")
    display(df)
    
    print("\n--- Abnormal Results Only (High Priority) ---")
    abnormal_df = df[df["Status"] == "Abnormal"]
    if not abnormal_df.empty:
        display(abnormal_df)
    else:
        print("Good news! No abnormalities detected in this batch.")
else:
    print("No data extracted from any images.")
# Out:
# --- All Extracted Data ---
#                                                   File  \
# 0                                           sample.png
# 1                                           sample.png
# 2                                           sample.png
# 3                                           sample.png
# 4                                           sample.png
# ..                                                 ...
# 157  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 158  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 159  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 160  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 161  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
#
#                       Parameter  Value      Unit    Status  \
# 0                    Hemoglobin   12.1      g/dl  Abnormal
# 1            Packed Cell Volume   42.5         %    Normal
# 2                         R.B.C    4.9  mill/emm    Normal
# 3              Mean Cell Volume   86.7        fl    Normal
# 4    Mean Cell Hemoglobin( Mch}   24.7      g/dl  Abnormal
# ..                          ...    ...       ...       ...
# 157               Lymphocytes *   16.2              Normal
# 158              Eosinophits 3/    7.0              Normal
# 159                   Monocytes    5.3              Normal
# 160                          1G    0.3              Normal
# 161                        Nrbc    0.0  mil/cumm  Abnormal
#
#                   Interpretation
# 0           Low (Ref: 13.0-17.0)
# 1    Reference range unavailable
# 2    Reference range unavailable
# 3    Reference range unavailable
# 4          High (Ref: 13.0-17.0)
# ..                           ...
# 157  Reference range unavailable
# 158  Reference range unavailable
# 159  Reference range unavailable
# 160  Reference range unavailable
# 161           Low (Ref: 4.5-5.5)
#
# [162 rows x 6 columns]
# --- Abnormal Results Only (High Priority) ---
#                                                   File  \
# 0                                           sample.png
# 4                                           sample.png
# 23   AHD-0425-PA-0007719_E-REPORTS_250427_2032@E.pd...
# 31   AHD-0425-PA-0007719_E-REPORTS_250427_2032@E.pd...
# 46   AHD-0425-PA-0008061_E-mahendrasinghdischargeca...
# 50   AHD-0425-PA-0008061_E-mahendrasinghdischargeca...
# 69   BLR-0425-PA-0036693_ARVIND REDDY REPALA 003669...
# 78   BLR-0425-PA-0039320_501848074 Final bill and D...
# 89   BLR-0425-PA-0040880_E-1745741621426SUSHILADEVI...
# 109  BLR-0425-PA-0041078_D CARD AND REPORT_11zon_27...
# 138  BLR-0425-PA-0041374_E-REPORT_250427_1413@E.pdf...
# 148  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 156  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
# 161  BLR-0425-PA-0041664_ef7835c4565245d6afdb7d905c...
#
#                       Parameter  Value      Unit    Status  \
# 0                    Hemoglobin  12.10      g/dl  Abnormal
# 4    Mean Cell Hemoglobin( Mch}  24.70      g/dl  Abnormal
# 23                  Lymphocytes  59.00         %  Abnormal
# 31                  Lymphocytes  62.30       /ul  Abnormal
# 46                   Hemoglobin  12.10      g/dl  Abnormal
# 50   Mean Cell Hemoglobin( Mch}  24.70      g/dl  Abnormal
# 69                  Neutrophils  76.80         %  Abnormal
# 78        Rbc  (Red  = 5.33 10°   6.00  mil/cumm  Abnormal
# 89                  Lymphocytes  16.00         %  Abnormal
# 109                  Hemoglobin   1.00      g/dl  Abnormal
# 138                         Rbc   4.00  mil/cumm  Abnormal
# 148                         Rbc   4.06  mil/cumm  Abnormal
# 156                 Neutrophils  74.50            Abnormal
# 161                        Nrbc   0.00  mil/cumm  Abnormal
#
#             Interpretation
# 0     Low (Ref: 13.0-17.0)
# 4    High (Ref: 13.0-17.0)
# 23       High (Ref: 20-40)
# 31       High (Ref: 20-40)
# 46    Low (Ref: 13.0-17.0)
# 50   High (Ref: 13.0-17.0)
# 69       High (Ref: 40-70)
# 78     High (Ref: 4.5-5.5)
# 89        Low (Ref: 20-40)
# 109   Low (Ref: 13.0-17.0)
# 138     Low (Ref: 4.5-5.5)
# 148     Low (Ref: 4.5-5.5)
# 156      High (Ref: 40-70)
# 161     Low (Ref: 4.5-5.5)
