# %%
import import_ipynb

from data_ingestion import load_dataset
from data_validator import validate_row
from model_parameter_interpreter import interpret_blood_report

from model2_pattern_engine import detect_patterns, calculate_total_risk
from model3_context_engine import adjust_by_context

# Load images from correct folder
df = load_dataset("../Milestone-1/Reports")

for i, row in df.iterrows():
    if not validate_row(row):
        continue

    # Model-1
    status = interpret_blood_report(row)

    # Model-2
    patterns = detect_patterns(row)

    # Model-3
    base_risk = calculate_total_risk(row)
    final_risk = adjust_by_context(row, base_risk)

    age = int(row["Age"])
    gender = row["Gender"]

    print(f"\nPatient {i+1}")
    print(f"Age - {age}")
    print(f"Gender - {gender}\n")

    # Match report order
    order = [
        "Glucose",
        "Cholesterol",
        "Hemoglobin",
        "White Blood Cells",
        "Red Blood Cells",
        "Platelets"
    ]

    for param in order:
        print(f"{param}: {float(row[param]):.2f} → {status[param]}")

    print("\nPatterns Detected:")
    if patterns:
        for name, score, severity in patterns:
            print(f"{name} (Risk Score - {score:.1f}, Severity - {severity})")
    else:
        print("None")

    print(f"\nFinal Risk Score: {final_risk}")
    print("-" * 60)
# Out:
# Patient 1
# Age - 83
# Gender - Male
#
# Glucose: 102.78 → Normal
# Cholesterol: 214.70 → High
# Hemoglobin: 11.43 → Low
# White Blood Cells: 12.29 → Low
# Red Blood Cells: 5.42 → Normal
# Platelets: 868491.00 → High
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.5, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 1.5, Severity - Medium)
# Bleeding Risk (Risk Score - 2.0, Severity - Medium)
#
# Final Risk Score: 6.5
# ------------------------------------------------------------
#
# Patient 2
# Age - 19
# Gender - Female
#
# Glucose: 88.10 → Normal
# Cholesterol: 189.38 → Normal
# Hemoglobin: 15.29 → Normal
# White Blood Cells: 10.87 → Low
# Red Blood Cells: 5.20 → Normal
# Platelets: 119762.00 → Low
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.2, Severity - Low)
# Bleeding Risk (Risk Score - 1.6, Severity - Low)
#
# Final Risk Score: 4
# ------------------------------------------------------------
#
# Patient 3
# Age - 56
# Gender - Male
#
# Glucose: 88.37 → Normal
# Cholesterol: 154.27 → Normal
# Hemoglobin: 11.50 → Low
# White Blood Cells: 4.31 → Low
# Red Blood Cells: 4.06 → Low
# Platelets: 79597.00 → Low
#
# Patterns Detected:
# Anemia Risk (Risk Score - 1.8, Severity - Medium)
# Immunity Risk (Risk Score - 1.8, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 1.8, Severity - Medium)
# Bleeding Risk (Risk Score - 2.4, Severity - Medium)
#
# Final Risk Score: 6.5
# ------------------------------------------------------------
#
# Patient 4
# Age - 55
# Gender - Female
#
# Glucose: 86.68 → Normal
# Cholesterol: 123.07 → Low
# Hemoglobin: 16.53 → High
# White Blood Cells: 9.12 → Low
# Red Blood Cells: 3.70 → Low
# Platelets: 166991.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.4, Severity - Medium)
# Immunity Risk (Risk Score - 1.8, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.4, Severity - Medium)
# Circulatory System Weakness (Risk Score - 2.4, Severity - Medium)
#
# Final Risk Score: 6
# ------------------------------------------------------------
#
# Patient 5
# Age - 42
# Gender - Male
#
# Glucose: 70.53 → Normal
# Cholesterol: 127.81 → Normal
# Hemoglobin: 9.41 → Low
# White Blood Cells: 5.15 → Low
# Red Blood Cells: 3.88 → Low
# Platelets: 225115.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.8, Severity - Medium)
# Anemia Risk (Risk Score - 2.1, Severity - Medium)
# Immunity Risk (Risk Score - 2.1, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 2.1, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.8, Severity - Medium)
# Circulatory System Weakness (Risk Score - 2.8, Severity - Medium)
#
# Final Risk Score: 7.5
# ------------------------------------------------------------
#
# Patient 6
# Age - 79
# Gender - Female
#
# Glucose: 85.24 → Normal
# Cholesterol: 257.48 → High
# Hemoglobin: 15.29 → Normal
# White Blood Cells: 10.79 → Low
# Red Blood Cells: 5.16 → Normal
# Platelets: 621695.00 → High
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.0, Severity - Medium)
# Immunity Risk (Risk Score - 1.5, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.0, Severity - Medium)
# Bleeding Risk (Risk Score - 2.0, Severity - Medium)
#
# Final Risk Score: 6
# ------------------------------------------------------------
#
# Patient 7
# Age - 16
# Gender - Male
#
# Glucose: 87.66 → Normal
# Cholesterol: 176.73 → Normal
# Hemoglobin: 13.87 → Normal
# White Blood Cells: 9.78 → Low
# Red Blood Cells: 5.10 → Normal
# Platelets: 574098.00 → High
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.2, Severity - Low)
# Bleeding Risk (Risk Score - 1.6, Severity - Low)
#
# Final Risk Score: 4.5
# ------------------------------------------------------------
#
# Patient 8
# Age - 68
# Gender - Female
#
# Glucose: 94.16 → Normal
# Cholesterol: 162.38 → Normal
# Hemoglobin: 10.53 → Low
# White Blood Cells: 4.92 → Low
# Red Blood Cells: 3.92 → Low
# Platelets: 618015.00 → High
#
# Patterns Detected:
# Anemia Risk (Risk Score - 1.8, Severity - Medium)
# Immunity Risk (Risk Score - 1.8, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 1.8, Severity - Medium)
# Bleeding Risk (Risk Score - 2.4, Severity - Medium)
#
# Final Risk Score: 7
# ------------------------------------------------------------
#
# Patient 9
# Age - 77
# Gender - Male
#
# Glucose: 70.28 → Normal
# Cholesterol: 180.77 → Normal
# Hemoglobin: 14.43 → Normal
# White Blood Cells: 9.22 → Low
# Red Blood Cells: 5.43 → Normal
# Platelets: 856490.00 → High
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.2, Severity - Low)
# Bleeding Risk (Risk Score - 1.6, Severity - Low)
#
# Final Risk Score: 5.5
# ------------------------------------------------------------
#
# Patient 10
# Age - 89
# Gender - Female
#
# Glucose: 102.96 → Normal
# Cholesterol: 266.71 → High
# Hemoglobin: 12.91 → Normal
# White Blood Cells: 9.04 → Low
# Red Blood Cells: 5.48 → Normal
# Platelets: 306810.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 1.2, Severity - Low)
# Immunity Risk (Risk Score - 0.9, Severity - Low)
# Chronic Inflammatory Stress (Risk Score - 1.2, Severity - Low)
#
# Final Risk Score: 4
# ------------------------------------------------------------
#
# Patient 11
# Age - 69
# Gender - Male
#
# Glucose: 70.19 → Normal
# Cholesterol: 215.61 → High
# Hemoglobin: 13.71 → Normal
# White Blood Cells: 9.52 → Low
# Red Blood Cells: 5.40 → Normal
# Platelets: 566601.00 → High
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.2, Severity - Low)
# Bleeding Risk (Risk Score - 1.6, Severity - Low)
#
# Final Risk Score: 5.5
# ------------------------------------------------------------
#
# Patient 12
# Age - 44
# Gender - Female
#
# Glucose: 64.87 → Low
# Cholesterol: 126.73 → Normal
# Hemoglobin: 17.13 → High
# White Blood Cells: 7.55 → Low
# Red Blood Cells: 4.05 → Low
# Platelets: 905372.00 → High
#
# Patterns Detected:
# Diabetic Risk (Risk Score - 3.6, Severity - Medium)
# Cardiovascular Risk (Risk Score - 3.6, Severity - Medium)
# Anemia Risk (Risk Score - 2.7, Severity - Medium)
# Immunity Risk (Risk Score - 2.7, Severity - Medium)
# Metabolic Syndrome Risk (Risk Score - 4.5, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 2.7, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 3.6, Severity - Medium)
# Circulatory System Weakness (Risk Score - 3.6, Severity - Medium)
# Metabolic Fatigue Syndrome (Risk Score - 4.5, Severity - Medium)
# Bleeding Risk (Risk Score - 3.6, Severity - Medium)
#
# Final Risk Score: 9
# ------------------------------------------------------------
#
# Patient 13
# Age - 78
# Gender - Female
#
# Glucose: 88.97 → Normal
# Cholesterol: 136.91 → Normal
# Hemoglobin: 9.60 → Low
# White Blood Cells: 9.31 → Low
# Red Blood Cells: 3.88 → Low
# Platelets: 209954.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.8, Severity - Medium)
# Anemia Risk (Risk Score - 2.1, Severity - Medium)
# Immunity Risk (Risk Score - 2.1, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 2.1, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.8, Severity - Medium)
# Circulatory System Weakness (Risk Score - 2.8, Severity - Medium)
#
# Final Risk Score: 8
# ------------------------------------------------------------
#
# Patient 14
# Age - 59
# Gender - Male
#
# Glucose: 88.10 → Normal
# Cholesterol: 133.71 → Normal
# Hemoglobin: 13.18 → Normal
# White Blood Cells: 5.44 → Low
# Red Blood Cells: 3.97 → Low
# Platelets: 400640.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.0, Severity - Medium)
# Immunity Risk (Risk Score - 1.5, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.0, Severity - Medium)
# Circulatory System Weakness (Risk Score - 2.0, Severity - Medium)
#
# Final Risk Score: 5.5
# ------------------------------------------------------------
#
# Patient 15
# Age - 67
# Gender - Female
#
# Glucose: 75.46 → Normal
# Cholesterol: 123.17 → Low
# Hemoglobin: 10.64 → Low
# White Blood Cells: 3.70 → Low
# Red Blood Cells: 3.58 → Low
# Platelets: 191487.00 → Normal
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.8, Severity - Medium)
# Anemia Risk (Risk Score - 2.1, Severity - Medium)
# Immunity Risk (Risk Score - 2.1, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 2.1, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.8, Severity - Medium)
# Circulatory System Weakness (Risk Score - 2.8, Severity - Medium)
#
# Final Risk Score: 8
# ------------------------------------------------------------
#
# Patient 16
# Age - 56
# Gender - Male
#
# Glucose: 77.07 → Normal
# Cholesterol: 252.67 → High
# Hemoglobin: 17.54 → High
# White Blood Cells: 7.11 → Low
# Red Blood Cells: 4.57 → Normal
# Platelets: 785286.00 → High
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.4, Severity - Medium)
# Immunity Risk (Risk Score - 1.8, Severity - Medium)
# Oxygen Transport Deficiency (Risk Score - 1.8, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.4, Severity - Medium)
# Bleeding Risk (Risk Score - 2.4, Severity - Medium)
#
# Final Risk Score: 6.5
# ------------------------------------------------------------
#
# Patient 17
# Age - 73
# Gender - Female
#
# Glucose: 116.39 → High
# Cholesterol: 154.96 → Normal
# Hemoglobin: 16.96 → High
# White Blood Cells: 6.58 → Low
# Red Blood Cells: 4.05 → Low
# Platelets: 426784.00 → Normal
#
# Patterns Detected:
# Immunity Risk (Risk Score - 0.9, Severity - Low)
#
# Final Risk Score: 4
# ------------------------------------------------------------
#
# Patient 18
# Age - 30
# Gender - Male
#
# Glucose: 86.76 → Normal
# Cholesterol: 254.62 → High
# Hemoglobin: 15.17 → Normal
# White Blood Cells: 5.74 → Low
# Red Blood Cells: 4.50 → Normal
# Platelets: 36011.00 → Low
#
# Patterns Detected:
# Cardiovascular Risk (Risk Score - 2.0, Severity - Medium)
# Immunity Risk (Risk Score - 1.5, Severity - Medium)
# Chronic Inflammatory Stress (Risk Score - 2.0, Severity - Medium)
# Bleeding Risk (Risk Score - 2.0, Severity - Medium)
#
# Final Risk Score: 5.5
# ------------------------------------------------------------
#
# Patient 19
# Age - 38
# Gender - Female
#
# Glucose: 88.10 → Normal
# Cholesterol: 189.38 → Normal
# Hemoglobin: 15.29 → Normal
# White Blood Cells: 10.87 → Low
# Red Blood Cells: 5.20 → Normal
# Platelets: 119762.00 → Low
#
# Patterns Detected:
# Immunity Risk (Risk Score - 1.2, Severity - Low)
# Bleeding Risk (Risk Score - 1.6, Severity - Low)
#
# Final Risk Score: 4
# ------------------------------------------------------------
#
# Patient 20
# Age - 59
# Gender - Male
#
# Glucose: 102.67 → Normal
# Cholesterol: 162.49 → Normal
# Hemoglobin: 12.89 → Normal
# White Blood Cells: 6.52 → Low
# Red Blood Cells: 5.38 → Normal
# Platelets: 205723.00 → Normal
#
# Patterns Detected:
# Immunity Risk (Risk Score - 0.6, Severity - Low)
#
# Final Risk Score: 2.5
# ------------------------------------------------------------
