# %%
# !pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pdfplumber in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (0.11.9)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from pdfplumber) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from pdfplumber) (5.3.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from pdfminer.six==20251230->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\priyanka sajnani\appdata\roaming\python\python313\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)

# %%
import pdfplumber
import re

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extract text from all pages of a PDF file
    """
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text + "\n"
    return text

# %%
pdf_path = "C:\\Users\\Priyanka Sajnani\\Downloads\\sample_report.pdf"  # ensure file exists

text = extract_text_from_pdf(pdf_path)

print("Text length:", len(text))
print("\nExtracted Text:\n")
print(text)
# Out:
# Text length: 117
#
# Extracted Text:
#
# Blood Test Report
# Hemoglobin: 10.8
# RBC: 3.8
# WBC: 9000
# Platelets: 200000
# Glucose: 135
# Bilirubin: 0.9
# Cholesterol: 180

# %%
patterns = {
    "hemoglobin": r"(Hemoglobin|Hb|HGB)\s*[:\-]?\s*([\d.]+)",
    "rbc": r"(RBC)\s*[:\-]?\s*([\d.]+)",
    "wbc": r"(WBC)\s*[:\-]?\s*([\d.]+)",
    "platelets": r"(Platelets|PLT)\s*[:\-]?\s*([\d.]+)",
    "glucose": r"(Glucose)\s*[:\-]?\s*([\d.]+)",
    "bilirubin": r"(Bilirubin)\s*[:\-]?\s*([\d.]+)",
    "cholesterol": r"(Cholesterol)\s*[:\-]?\s*([\d.]+)"
}

# %%
def extract_parameters(text):
    """
    Extract blood parameters using regex patterns
    """
    results = {}
    for param, pattern in patterns.items():
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            results[param] = float(match.group(2))
    return results

# %%
params = extract_parameters(text)

print("🔬 Extracted Parameters:")
print(params)
# Out:
# 🔬 Extracted Parameters:
# {'hemoglobin': 10.8, 'rbc': 3.8, 'wbc': 9000.0, 'platelets': 200000.0, 'glucose': 135.0, 'bilirubin': 0.9, 'cholesterol': 180.0}

# %%
def validate_parameters(params):
    """
    Validate extracted parameter values
    """
    validated = {}
    for key, value in params.items():
        if value is not None and value > 0:
            validated[key] = value
    return validated


validated_params = validate_parameters(params)

print("✅ Validated Parameters:")
print(validated_params)
# Out:
# ✅ Validated Parameters:
# {'hemoglobin': 10.8, 'rbc': 3.8, 'wbc': 9000.0, 'platelets': 200000.0, 'glucose': 135.0, 'bilirubin': 0.9, 'cholesterol': 180.0}

# %%
reference_ranges = {
    "hemoglobin": (12, 16),
    "rbc": (4.2, 5.9),
    "wbc": (4000, 11000),
    "platelets": (150000, 450000),
    "glucose": (70, 110),
    "bilirubin": (0.1, 1.2),
    "cholesterol": (125, 200)
}

# %%
def interpret_parameter(param, value):
    """
    Classify parameter as Low / Normal / High
    """
    low, high = reference_ranges[param]
    if value < low:
        return "Low"
    elif value > high:
        return "High"
    else:
        return "Normal"

# %%
print("📊 Parameter Interpretation Results:\n")

for param, value in validated_params.items():
    status = interpret_parameter(param, value)
    print(f"{param.capitalize():15} : {value} → {status}")
# Out:
# 📊 Parameter Interpretation Results:
#
# Hemoglobin      : 10.8 → Low
# Rbc             : 3.8 → Low
# Wbc             : 9000.0 → Normal
# Platelets       : 200000.0 → Normal
# Glucose         : 135.0 → High
# Bilirubin       : 0.9 → Normal
# Cholesterol     : 180.0 → Normal
