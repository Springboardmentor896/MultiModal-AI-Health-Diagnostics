# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath('..'))

from ingestion.images_parser import extract_text
from extraction.parameter_extraction import extract_parameters
from models.parameter_interpreter import ParameterInterpreter

# CONFIG
IMAGE_PATH = "/home/quasar_011/Developer/v_intern/data/sample/sample.png" # Point to one of your Bajaj images
REF_RANGES = "/home/quasar_011/Developer/test/validation/reference_ranges.json"

# 1. Ingestion
print(f"Reading: {IMAGE_PATH}")
raw_text = extract_text(IMAGE_PATH)
print("--- OCR Raw Text ---")
print(raw_text[:300])

# 2. Extraction
print("\n--- Extracted Parameters ---")
data = extract_parameters(raw_text)
df = pd.DataFrame(data)
display(df)

# 3. Model 1: Interpretation
print("\n--- Model 1 Analysis ---")
interpreter = ParameterInterpreter(REF_RANGES)
analyzed_data = interpreter.analyze(data)
df_analyzed = pd.DataFrame(analyzed_data)
display(df_analyzed)
# Out:
# Reading: /home/quasar_011/Developer/v_intern/data/sample/sample.png
# --- OCR Raw Text ---
# loot Report
# N                                                                      K.P. Patil Building,
# SHREE  DIAGNOSTIC                Near Shivaji Maharaj Statue,
# “am      ©. 7 A¥ ee ame weve CD        :                             Mohopada, Tal. Khalapur,
# VTA           y.%
# CLINICAL: LABORATORY;
#
# --- Extracted Parameters ---
#                      Parameter     Value        Unit  \
# 0                    am      .       7.0          A¥
# 1                   Hemoglobin      12.1       gm/dl
# 2     Packed Cell Volume (HCT)      42.5           %
# 3                 R.B.C. Count       4.9    mill/cmm
# 4        Mean Cell Volume(MCV)      86.7          fl
# 5   Mean Cell Hemoglobin( MCH)      24.7          pe
# 6      Mean Cell Hb Conc(MCHC)      28.5           %
# 7              Total WBC Count   13600.0  cells/cumm
# 8                    Monocytes       6.0           %
# 9     Absolute Monocytes Count     816.0       /cumm
# 10              Platelet Count  502000.0  cells/cumm
# 11                        pnts       3.0
#
#                             Range
# 0                     Unavailable
# 1                       13.0-17.0
# 2                           40-50
# 3                         4.5-5.5
# 4                          83-101
# 5                           27-33
# 6                          32 -38
# 7                      4000-11000
# 8                            0-10
# 9                        200-1000
# 10                    Unavailable
# 11                    Unavailable
# --- Model 1 Analysis ---
#                      Parameter     Value        Unit  \
# 0                    am      .       7.0          A¥
# 1                   Hemoglobin      12.1       gm/dl
# 2     Packed Cell Volume (HCT)      42.5           %
# 3                 R.B.C. Count       4.9    mill/cmm
# 4        Mean Cell Volume(MCV)      86.7          fl
# 5   Mean Cell Hemoglobin( MCH)      24.7          pe
# 6      Mean Cell Hb Conc(MCHC)      28.5           %
# 7              Total WBC Count   13600.0  cells/cumm
# 8                    Monocytes       6.0           %
# 9     Absolute Monocytes Count     816.0       /cumm
# 10              Platelet Count  502000.0  cells/cumm
# 11                        pnts       3.0
#
#                             Range             Standard_Name    Status  \
# 0                     Unavailable                 Am      .    Normal
# 1                       13.0-17.0                Hemoglobin  Abnormal
# 2                           40-50                       PCV    Normal
# 3                         4.5-5.5                 RBC Count    Normal
# 4                          83-101                       MCV    Normal
# 5                           27-33                       MCH  Abnormal
# 6                          32 -38                      MCHC  Abnormal
# 7                      4000-11000                 Total WBC  Abnormal
# 8                            0-10                 Monocytes    Normal
# 9                        200-1000  Absolute Monocytes Count    Normal
# 10                    Unavailable            Platelet Count  Abnormal
# 11                    Unavailable                      Pnts    Normal
#
#                  Flag
# 0   Range Unavailable
# 1                 Low
# 2       Within Limits
# 3       Within Limits
# 4       Within Limits
# 5                 Low
# 6                 Low
# 7                High
# 8       Within Limits
# 9   Range Unavailable
# 10               High
# 11  Range Unavailable
