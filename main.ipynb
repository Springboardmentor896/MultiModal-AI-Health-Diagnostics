# %%
import import_ipynb
from blood_report_parser import parse_reports
from evaluation import evaluate
# Out:
# Patient 1
# Age - 83
#
# Hemoglobin: 0.713631 → High
# Glucose: 0.739597 → High
# Cholesterol: 0.650198 → Normal
# White Blood Cells: 0.687433 → High
# Red Blood Cells: 0.529895 → Normal
#
#
# Patterns Detected:
# Infection/Inflammation risk (Risk Score - 2.5, Severity - Medium)
# ------------------------------------------------------------
#
# Patient 2
# Age - 44
#
# Hemoglobin: 0.944893 → High
# Glucose: 0.121786 → Low
# Cholesterol: 0.023058 → Low
# White Blood Cells: 0.507711 → Normal
# Red Blood Cells: 0.403033 → Normal
#
#
# Patterns Detected:
# None
# ------------------------------------------------------------
#
# Patient 3
# Age - 59
#
# Hemoglobin: 0.544560 → Normal
# Glucose: 0.452539 → Normal
# Cholesterol: 0.116135 → Low
# White Blood Cells: 0.294538 → Low
# Red Blood Cells: 0.382021 → Normal
#
#
# Patterns Detected:
# None
# ------------------------------------------------------------
#
# Patient 4
# Age - 67
#
# Hemoglobin: 0.419957 → Normal
# Glucose: 0.136609 → Low
# ...
