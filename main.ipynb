# %%
# %run main.py
# Out:
# Extracted Values:
# Hemoglobin: 10.2
# WBC: 7800.0
# RBC: 5.1
# Platelets: 320000.0
# Glucose: 68.0
#
# Status:
# Hemoglobin: Low
# WBC: Normal
# RBC: Normal
# Platelets: Normal
# Glucose: Low
#
# Interpretation:
# Hemoglobin: Hemoglobin is below normal range.
# WBC: WBC is within normal range.
# RBC: RBC is within normal range.
# Platelets: Platelets is within normal range.
# Glucose: Glucose is below normal range.
